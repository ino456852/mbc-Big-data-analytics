# %%
moon = open('./data/speech_moon.txt',encoding='utf-8').read()
moon
# Out:
# '정권교체 하겠습니다!\n  정치교체 하겠습니다!\n  시대교체 하겠습니다!\n  \n  ‘불비불명(不飛不鳴)’이라는 고사가 있습니다. 남쪽 언덕 나뭇가지에 앉아, 3년 동안 날지도 울지도 않는 새. 그러나 그 새는 한번 날면 하늘 끝까지 날고, 한번 울면 천지를 뒤흔듭니다.\n\n그 동안 정치와 거리를 둬 왔습니다. 그러나 암울한 시대가 저를 정치로 불러냈습니다. 더 이상 남쪽 나뭇가지에 머무를 수 없었습니다. 이제 저는 국민과 함께 높이 날고 크게 울겠습니다. 오늘 저는 제18대 대통령선거 출마를 국민 앞에 엄숙히 선언합니다.\n\n\n‘우리나라 대통령’이 되겠습니다.\n\n\n존경하는 국민 여러분!\n  \n  저는 대통령이 되겠습니다. 우리나라 대통령이 되겠습니다. 소수 특권층의 나라가 아니라 보통사람들이 주인인 ‘우리나라’, 네 편 내 편 편가르지 않고 함께 가는 우리나라, ‘우리’라는 말이 조금도 부끄럽지 않은, 진정한 ‘우리나라’의 대통령이 되겠습니다.\n\n지금까지 우리 보통사람들은 날지도 울지도 못하는 새였습니다. 나라의 주인으로 행세하지 못했고, 주인으로 대접받지 못했습니다. 나서서 말도 하지 못했습니다. 이제 몸을 일으켜 날아야 합니다. 당당하게 말하고 정치에 참여해야 합니다.\n\n제가 추구하는 ‘우리나라’는 정치인에게 맡겨놓는 나라가 아니라 시민이 직접 정치와 정책과정에 참여하는 나라입니다. 저는 시민과 동행하는 정치를 하고 싶습니다. 제가 추구하는 ‘우리나라’는 특권과 불평등의 나라가 아니라, 보통사람들이 함께 기회를 가지는 공평하고 정의로운 나라입니다.\n\n이제 권력과 돈을 가진 집단이 나라를 그들 마음대로 움직이던 시대는 끝났습니다. 힘없는 사람들에게 끝없이 희생을 강요하던 낡은 경제, 낡은 정치, 낡은 권력도 모두 끝났습니다. 오늘 저 문재인은 우리나라를 우리 모두의 나라로 선언합니다.\n\n국민이 모두 아픕니다.\n\n제가 높이 날고 크게 울겠다고 결심한 이유는 보통사람들의 삶이 너무 고달프고, 우리가 처한 현실이 너무도 
# ...

# %%
import re
moon = re.sub('[^가-힣]',' ',moon)
moon
# Out:
# '정권교체 하겠습니다    정치교체 하겠습니다    시대교체 하겠습니다        불비불명       이라는 고사가 있습니다  남쪽 언덕 나뭇가지에 앉아   년 동안 날지도 울지도 않는 새  그러나 그 새는 한번 날면 하늘 끝까지 날고  한번 울면 천지를 뒤흔듭니다   그 동안 정치와 거리를 둬 왔습니다  그러나 암울한 시대가 저를 정치로 불러냈습니다  더 이상 남쪽 나뭇가지에 머무를 수 없었습니다  이제 저는 국민과 함께 높이 날고 크게 울겠습니다  오늘 저는 제  대 대통령선거 출마를 국민 앞에 엄숙히 선언합니다     우리나라 대통령 이 되겠습니다    존경하는 국민 여러분       저는 대통령이 되겠습니다  우리나라 대통령이 되겠습니다  소수 특권층의 나라가 아니라 보통사람들이 주인인  우리나라   네 편 내 편 편가르지 않고 함께 가는 우리나라   우리 라는 말이 조금도 부끄럽지 않은  진정한  우리나라 의 대통령이 되겠습니다   지금까지 우리 보통사람들은 날지도 울지도 못하는 새였습니다  나라의 주인으로 행세하지 못했고  주인으로 대접받지 못했습니다  나서서 말도 하지 못했습니다  이제 몸을 일으켜 날아야 합니다  당당하게 말하고 정치에 참여해야 합니다   제가 추구하는  우리나라 는 정치인에게 맡겨놓는 나라가 아니라 시민이 직접 정치와 정책과정에 참여하는 나라입니다  저는 시민과 동행하는 정치를 하고 싶습니다  제가 추구하는  우리나라 는 특권과 불평등의 나라가 아니라  보통사람들이 함께 기회를 가지는 공평하고 정의로운 나라입니다   이제 권력과 돈을 가진 집단이 나라를 그들 마음대로 움직이던 시대는 끝났습니다  힘없는 사람들에게 끝없이 희생을 강요하던 낡은 경제  낡은 정치  낡은 권력도 모두 끝났습니다  오늘 저 문재인은 우리나라를 우리 모두의 나라로 선언합니다   국민이 모두 아픕니다   제가 높이 날고 크게 울겠다고 결심한 이유는 보통사람들의 삶이 너무 고달프고  우리가 처한 현실이 너무도 엄중하기 때문입니다  근본적인 혁신  거대한
# ...

# %%
# hannanum 만들기
import konlpy
hannanum = konlpy.tag.Hannanum()

# 명사 추출하기
hannanum.nouns("대한민국의 영토는 한반도와 그 부속도서로 한다")
# Out:
# ['대한민국', '영토', '한반도', '부속도서']

# %%
hannanum.morphs("대한민국의 영토는 한반도와 그 부속도서로 한다")
# Out:
# ['대한민국', '의', '영토', '는', '한반도', '와', '그', '부속도서', '로', '하', 'ㄴ다']

# %%
# 품사코드
hannanum.pos("대한민국의 영토는 한반도와 그 부속도서로 한다")
# Out:
# [('대한민국', 'N'),
#  ('의', 'J'),
#  ('영토', 'N'),
#  ('는', 'J'),
#  ('한반도', 'N'),
#  ('와', 'J'),
#  ('그', 'M'),
#  ('부속도서', 'N'),
#  ('로', 'J'),
#  ('하', 'P'),
#  ('ㄴ다', 'E')]

# %%
# 품사코드 설명
hannanum.tagset
# Out:
# {'E': '어미',
#  'EC': '연결 어미',
#  'EF': '종결 어미',
#  'EP': '선어말어미',
#  'ET': '전성 어미',
#  'F': '외국어',
#  'I': '독립언',
#  'II': '감탄사',
#  'J': '관계언',
#  'JC': '격조사',
#  'JP': '서술격 조사',
#  'JX': '보조사',
#  'M': '수식언',
#  'MA': '부사',
#  'MM': '관형사',
#  'N': '체언',
#  'NB': '의존명사',
#  'NC': '보통명사',
#  'NN': '수사',
#  'NP': '대명사',
#  'NQ': '고유명사',
#  'P': '용언',
#  'PA': '형용사',
#  'PV': '동사',
#  'PX': '보조 용언',
#  'S': '기호',
#  'X': '접사',
#  'XP': '접두사',
#  'XS': '접미사'}

# %%
# 연설문에서 명사 추출하기
nouns = hannanum.nouns(moon)
nouns
# Out:
# ['정권교체',
#  '정치교체',
#  '시대교체',
#  '불비불명',
#  '고사',
#  '남쪽',
#  '언덕',
#  '나뭇가지',
#  '년',
#  '동안',
#  '새',
#  '한번',
#  '하늘',
#  '끝',
#  '한번',
#  '천지',
#  '동안',
#  '정치',
#  '거리',
#  '암울한',
#  '시대',
#  '저',
#  '정치',
#  '이상',
#  '남쪽',
#  '나뭇가지',
#  '수',
#  '저',
#  '국민',
#  '오늘',
#  '저',
#  '저',
#  '대',
#  '대통령선거',
#  '출마',
#  '국민',
#  '앞',
#  '선언',
#  '우리나라',
#  '대통령',
#  '존경',
#  '국민',
#  '여러분',
#  '저',
#  '대통령',
#  '우리나라',
#  '대통령',
#  '소수',
#  '특권층',
#  '나라',
#  '보통사람들',
#  '주인',
#  '우리나라',
#  '네',
#  '편',
#  '내',
#  '편',
#  '편가르지',
#  '우리나라',
#  '우리',
#  '라',
#  '말',
#  '진정한',
#  '우리나라',
#  '의',
#  '대통령',
#  '지금',
#  '우리',
#  '보통사람들',
#  '새',
#  '나라',
#  '주인',
#  '행세',
#  '주인',
#  '대접',
#  '말',
#  '몸',
#  '당당',
#  '말',
#  '정치',
#  '참여',
#  '저',
#  '추구',
#  '우리나라',
#  '정치인',
#  '나라',
#  '시민',
#  '정치',
#  '정책과정',
#  '참여',
#  '나라',
#  '저',
#  '시민',
#  '동행',
#  '정치',
#  '저',
#  '추구',
#  '우리나라',
#  '특권',
#  '불평등',
#  '나라',
#  '보통사람들',
#  '기회',
#  '공평',
#  '정의로운',
#  '나라',
#  '권력',
#  '돈',
# ...

# %%
# 데이터 프레임으로 변환
import pandas as pd
df_word = pd.DataFrame({'word' : nouns})
df_word
# Out:
#       word
# 0     정권교체
# 1     정치교체
# 2     시대교체
# 3     불비불명
# 4       고사
# ...    ...
# 1408    모두
# 1409    주인
# 1410   진정한
# 1411  우리나라
# 1412   대통령
#
# [1413 rows x 1 columns]

# %%
# 글자 수 추가
df_word['count'] = df_word['word'].str.len()
df_word
# Out:
#       word  count
# 0     정권교체      4
# 1     정치교체      4
# 2     시대교체      4
# 3     불비불명      4
# 4       고사      2
# ...    ...    ...
# 1408    모두      2
# 1409    주인      2
# 1410   진정한      3
# 1411  우리나라      4
# 1412   대통령      3
#
# [1413 rows x 2 columns]

# %%
# 두 글자 이상 단어만 남기기
df_word = df_word.query('count >= 2')
df_word.sort_values('count')
# Out:
#           word  count
# 712         국민      2
# 1164        가사      2
# 1163        숙제      2
# 1162        평등      2
# 644         확대      2
# ...        ...    ...
# 707     평생학습체제      6
# 1268    군사대결지대      6
# 173     성적스트레스      6
# 978   고용영향평가제도      8
# 1055  국가일자리위원회      8
#
# [1187 rows x 2 columns]

# %%
words = df_word['word'].value_counts()
words
# Out:
# word
# 나라      19
# 일자리     19
# 국민      18
# 우리      17
# 대통령     12
#         ..
# 경영       1
# 목소리      1
# 침해       1
# 권익       1
# 패배주의     1
# Name: count, Length: 710, dtype: int64

# %%
words.head(20)
# Out:
# word
# 나라      19
# 일자리     19
# 국민      18
# 우리      17
# 대통령     12
# 대한민국    11
# 확대      11
# 우리나라    10
# 정치      10
# 사회       9
# 성장       9
# 사람       9
# 평화       8
# 복지       8
# 복지국가     8
# 정부       7
# 산업       7
# 추진       7
# 교육       6
# 경쟁       6
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams.update({'font.family'    : 'Malgun Gothic',  # 한글 폰트 설정
                     'figure.dpi'     : '120',            # 해상도 설정
                     'figure.figsize' : [6.5, 6]})        # 가로 세로 크기 설정

# %%
words.head(20).plot.bar(rot=45)
# Out:
# <Axes: xlabel='word'>

# %%
font = './data/DoHyeon-Regular.ttf'

# %%
dic_word = words.to_dict()
dic_word
# Out:
# {'나라': 19,
#  '일자리': 19,
#  '국민': 18,
#  '우리': 17,
#  '대통령': 12,
#  '대한민국': 11,
#  '확대': 11,
#  '우리나라': 10,
#  '정치': 10,
#  '사회': 9,
#  '성장': 9,
#  '사람': 9,
#  '평화': 8,
#  '복지': 8,
#  '복지국가': 8,
#  '정부': 7,
#  '산업': 7,
#  '추진': 7,
#  '교육': 6,
#  '경쟁': 6,
#  '세상': 6,
#  '대통령의': 5,
#  '공평': 5,
#  '경제': 5,
#  '정규직': 5,
#  '보통사람들': 5,
#  '상생': 5,
#  '기회': 4,
#  '요구': 4,
#  '사회적': 4,
#  '전환': 4,
#  '강화': 4,
#  '아래': 4,
#  '투자': 4,
#  '중소기업': 4,
#  '창출': 4,
#  '약자': 4,
#  '고통': 4,
#  '모델': 4,
#  '희망': 4,
#  '결과': 4,
#  '역사': 4,
#  '때문': 4,
#  '여성': 4,
#  '정의': 4,
#  '주인': 4,
#  '아이들': 4,
#  '담쟁': 4,
#  '가치': 3,
#  '군대': 3,
#  '채택': 3,
#  '부담': 3,
#  '관계': 3,
#  '시민': 3,
#  '원전': 3,
#  '성장전략': 3,
#  '국가': 3,
#  '질서': 3,
#  '신산업': 3,
#  '소수': 3,
#  '세계': 3,
#  '교육혁신': 3,
#  '공정': 3,
#  '여러분': 3,
#  '원칙': 3,
#  '과도한': 3,
#  '개선': 3,
#  '변화': 3,
#  '강자': 3,
#  '그것': 3,
#  '이명박': 3,
#  '지원': 3,
#  '국민들': 3,
#  '특권': 3,
#  '지방': 3,
#  '가지': 3,
#  '행복': 3,
#  '문재인': 3,
#  '양극화': 3,
#  '노인': 3,
# ...

# %%
# wc 만들기
from wordcloud import WordCloud
wc = WordCloud(random_state = 1234,         # 난수 고정
               font_path = font,            # 폰트 설정
               width = 400,                 # 가로 크기
               height = 400,                # 세로 크기
               background_color = 'white')  # 배경색

# %%
# 워드 클라우드 만들기
img_wordcloud = wc.generate_from_frequencies(dic_word);

# 워드 클라우드 출력하기
plt.figure(figsize = (7, 7))  # 가로, 세로 크기 설정
plt.axis('off')                 # 테두리 선 없애기
plt.imshow(img_wordcloud)       # 워드 클라우드 출력

# %%
# 데이터 불러오기
df = pd.read_csv('./data/news_comment_BTS.csv', encoding = 'UTF-8')

# 데이터 살펴보기
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   reg_time  1200 non-null   object
#  1   reply     1200 non-null   object
#  2   press     1200 non-null   object
#  3   title     1200 non-null   object
#  4   url       1200 non-null   object
# dtypes: object(5)
# memory usage: 47.0+ KB

# %%
df.head()
# Out:
#               reg_time                                              reply  \
# 0  2020-09-01 22:58:09                                  국보소년단<U+0001F49C>
# 1  2020-09-01 09:56:46                                       아줌마가 들어도 좋더라
# 2  2020-09-01 09:08:06  팩트체크\n\n현재 빌보드 HOT 100\n\n1위  방탄소년단[BTS]\n2위 C...
# 3  2020-09-01 08:52:32            방탄소년단이 한국사람이라 너무 자랑스러워요 ㅠㅠ 우리오래오래 함께하자!
# 4  2020-09-01 08:36:33                대단한 BTS, 월드 클래스는 다르네^^ 좋은 소식!! 응원해요
#
#   press                                  title  \
# 0  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
# 1  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
# 2  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
# 3  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
# 4  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
#
#                                                  url
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# ...

# %%
# 불필요한 문자 제거하기
df['reply'] = df['reply'].str.replace('[^가-힣]', ' ', regex = True)
df['reply'].head()
# Out:
# 0                                    국보소년단
# 1                                         아줌마가 들어도 좋더라
# 2    팩트체크  현재 빌보드           위  방탄소년단       위       ...
# 3              방탄소년단이 한국사람이라 너무 자랑스러워요    우리오래오래 함께하자
# 4                  대단한      월드 클래스는 다르네   좋은 소식   응원해요
# Name: reply, dtype: object

# %%
# kkma 만들기
import konlpy
kkma = konlpy.tag.Kkma()

# %%
# 명사 추출 - apply() 활용
nouns = df['reply'].apply(kkma.nouns)
nouns
# Out:
# 0                                        [국보, 국보소년단, 소년단]
# 1                                                   [아줌마]
# 2                   [팩트, 팩트체크, 체크, 보드, 위, 방탄, 방탄소년단, 소년단]
# 3              [방탄, 방탄소년단, 소년단, 한국, 한국사람, 사람, 자랑, 우리, 하자]
# 4                                       [월드, 클래스, 소식, 응원]
#                               ...
# 1195                                                   []
# 1196                                      [우리, 탄, 자랑, 사랑]
# 1197                                              [애, 군대]
# 1198                                     [군, 군면제급, 면제, 급]
# 1199    [자랑, 축하, 김, 김남, 남, 김석진, 민, 민윤기, 윤기, 정, 정호석, 호석...
# Name: reply, Length: 1200, dtype: object

# %%
nouns
# Out:
# 0                                        [국보, 국보소년단, 소년단]
# 1                                                   [아줌마]
# 2                   [팩트, 팩트체크, 체크, 보드, 위, 방탄, 방탄소년단, 소년단]
# 3              [방탄, 방탄소년단, 소년단, 한국, 한국사람, 사람, 자랑, 우리, 하자]
# 4                                       [월드, 클래스, 소식, 응원]
#                               ...
# 1195                                                   []
# 1196                                      [우리, 탄, 자랑, 사랑]
# 1197                                              [애, 군대]
# 1198                                     [군, 군면제급, 면제, 급]
# 1199    [자랑, 축하, 김, 김남, 남, 김석진, 민, 민윤기, 윤기, 정, 정호석, 호석...
# Name: reply, Length: 1200, dtype: object

# %%
nouns = nouns.explode()
nouns
# Out:
# 0          국보
# 0       국보소년단
# 0         소년단
# 1         아줌마
# 2          팩트
#         ...
# 1199      박지민
# 1199      김태형
# 1199        전
# 1199      전정국
# 1199       정국
# Name: reply, Length: 9353, dtype: object

# %%
# 데이터 프레임 만들기
df_word = pd.DataFrame({'word' : nouns})

# 글자 수 추가
df_word['count'] = df_word['word'].str.len()

# 두 글자 이상 단어만 남기기
df_word = df_word.query('count >= 2')
df_word
# Out:
#        word  count
# 0        국보    2.0
# 0     국보소년단    5.0
# 0       소년단    3.0
# 1       아줌마    3.0
# 2        팩트    2.0
# ...     ...    ...
# 1199     박지    2.0
# 1199    박지민    3.0
# 1199    김태형    3.0
# 1199    전정국    3.0
# 1199     정국    2.0
#
# [7002 rows x 2 columns]

# %%
words = df_word.value_counts()
words
# Out:
# word   count
# 방탄     2.0      280
# 축하     2.0      236
# 자랑     2.0      205
# 소년단    3.0      144
# 방탄소년단  5.0      136
#                ...
# 실력있음   4.0        1
# 다음주면   4.0        1
# 신화     2.0        1
# 신중     2.0        1
# 스을적    3.0        1
# Name: count, Length: 2168, dtype: int64

# %%
top20 = words.head(20)
top20.plot.barh()
# Out:
# <Axes: ylabel='word,count'>

# %%
# wc 만들기
from wordcloud import WordCloud
wc = WordCloud(random_state = 1234,         # 난수 고정
               font_path = font,            # 폰트 설정
               width = 400,                 # 가로 크기
               height = 400,                # 세로 크기
               background_color = 'white')  # 배경색

# %%
# 딕셔너리로 변환 (generate_from_frequencies에 필요)
dic_word = words.to_dict()

# 워드 클라우드 만들기
from wordcloud import WordCloud
wc = WordCloud(random_state=1234,
               font_path=font,
               width=400,
               height=400,
               background_color='white')

# 워드 클라우드 생성
img_wordcloud = wc.generate_from_frequencies(dic_word)

# 출력
plt.figure(figsize=(5, 5))
plt.axis('off')
plt.imshow(img_wordcloud)
plt.show()

# %%
def web_get(url):
    # requests 패키지 가져오기
    import requests               

    # 가져올 url 문자열로 입력

    # requests의 get함수를 이용해 해당 url로 부터 html이 담긴 자료를 받아옴
    response = requests.get(url)    

    # 우리가 얻고자 하는 html 문서가 여기에 담기게 됨
    html_text = response.text
    return html_text # 함수끝

def find_text(html_text, selector):
    # BeautifulSoup 패키지 불러오기
    # 주로 bs로 이름을 간단히 만들어서 사용함
    from bs4 import BeautifulSoup as bs

    # html을 잘 정리된 형태로 변환
    soup = bs(html_text, 'html.parser')
    
    return soup.select_one(selector).get_text()


def find_text_list(html_text, selector):
    from bs4 import BeautifulSoup as bs
    # html을 잘 정리된 형태로 변환
    soup = bs(html_text, 'html.parser')
    tag_list = soup.select(selector)
    
    result_list = []
    for tag in tag_list:
        result_list.append(tag.get_text())
    return result_list

if __name__ == "__main__":
    html = web_get("https://www.yna.co.kr/")
    title_list = find_text_list(html,".list-type001 .title01")
# Out:
# 李대통령 "막을 수 있는데 부주의로 사고나면 엄정히 책임 물을 것"
# 코스피 날개 달았다…1.5% 오르며 11개월만에 2,810대 복귀
# "서울교대 늘봄 예산 12억원 중 일부 리박스쿨 측 지급 정황"
# 군 "지난주 동해 NLL 표류해 넘은 北주민 4명 발견"
# 경찰, 처자식 살해사건 초기 대응 '부실'…수사기관 공조 미흡
# 기재부 2차 추경 논의 착수…예산실장 주재 각 부처 회의
# 대법 "교실 '몰래녹음' 전제로 한 진술도 증거로 사용 불가"
# 대법, '쌍방울 대북송금' 이화영 징역 7년8개월 확정
# 대법 '김학의 불법출금 혐의' 차규근·이광철·이규원 무죄 확정
# 한수원, 체코 두코바니 현장건설소 개소…2036년 원전 완공 목표
# '고1 학평 영어 유출' 17개 시도교육청 공동으로 수사의뢰
# 트럼프-시진핑 통화 임박했나…中 '돌발사태 경계심'이 변수
# 김정은, 러 쇼이구에 "북러조약 조항들 준수할 것…무조건 지지"
# 조희대, 대법관 증원법에 직접 언급 "공론장 희망…국회 협의"
# 박성재 "다수 뜻 아래 권한 무절제 사용은 민주주의 반해"
# 현충일 연휴 전국 대체로 맑음…제주엔 토요일 밤부터 비
# 트럼프, 하버드대 유학·연수하려는 외국인 비자 제한
# 세계 환경의날…"우리가 플라스틱 오염 피해자이자 원인제공자"
# 전국 선거사범 2천565명 적발…3년 전 대선보다 1천여명 증가
# 광주 시내버스 파업…시민들 불편·교통 대란은 발생 안 해
# 태안화력 사망사고에 준특별감독…노동계 "강력처벌"
# 경찰 '설계 특혜의혹' 광주시청 압수수색…姜시장 "수사권남용"
# '이선균 수사 정보 유출' 경찰관·검찰수사관 불구속 기소
# 서울 아파트값, 18주 연속 올라…상승폭 확대
# 울산서 현직 경찰관 또 음주운전…시민 신고로 적발
# 온라인상 故김하늘 양 명예훼손 글 게시한 5명 모두 검거
# 인도 크리켓 우승 축하장서 압사사고…"11명 사망·47명 부상"

# %%
df = pd.DataFrame({"word":title_list})

# %%
hannanum = konlpy.tag.Hannanum()
df['word'] = df['word'].str.replace('[^가-힣]', ' ', regex = True)
nouns = df['word'].apply(hannanum.nouns)
nouns = nouns.explode()
nouns
# Out:
# 0      대통령
# 0        막
# 0        수
# 0      부주의
# 0        책
#       ...
# 26    압사사고
# 26       명
# 26      사망
# 26       명
# 26      부상
# Name: word, Length: 208, dtype: object

# %%
news_title = pd.DataFrame({'word' : nouns})

# 글자 수 추가
news_title['count'] = news_title['word'].str.len()

# 두 글자 이상 단어만 남기기
news_title = news_title.query('count >= 2')
news_title
# Out:
#     word  count
# 0    대통령      3
# 0    부주의      3
# 1    코스피      3
# 1     날개      2
# 1     개월      2
# ..   ...    ...
# 26    우승      2
# 26  축하장서      4
# 26  압사사고      4
# 26    사망      2
# 26    부상      2
#
# [174 rows x 2 columns]

# %%
words = news_title['word'].value_counts()
# 딕셔너리로 변환 (generate_from_frequencies에 필요)
dic_word = words.to_dict()

# 워드 클라우드 만들기
from wordcloud import WordCloud
wc = WordCloud(random_state=1234,
               font_path=font,
               width=400,
               height=400,
               background_color='white')

# 워드 클라우드 생성
img_wordcloud = wc.generate_from_frequencies(dic_word)

# 출력
plt.figure(figsize=(5, 5))
plt.axis('off')
plt.imshow(img_wordcloud)
plt.show()

# %%
def find_text_list(html_text, selector):
    from bs4 import BeautifulSoup as bs
    # html을 잘 정리된 형태로 변환
    soup = bs(html_text, 'html.parser')
    tag_list = soup.select(selector)
    
    result_list = []
    for tag in tag_list:
        result_list.append(tag.get_text())
    return result_list

if __name__ == "__main__":
    html = web_get("https://www.fnnews.com/")
    title_list = find_text_list(html,"strong.tit_thumb  a")
    print(title_list)
# Out:
# [' 李대통령, 국토부에 해수부 부산 신속 이전 지시', '이재명 정부 국정과제 밑그림 그릴 국정기획위 내주 출범', '김민석 총리 후보자 “제2 IMF 같이 어려운 상황...첫째 둘째 셋째도 민생”', '李대통령, 이완규·함상훈 헌법재판관 지명 철회', "'먹사니즘' 해결할 준비 되셨나요?", '총수의 봉투, 대통령의 봉투', '국정은 실력으로 이끌어야 한다', '신 과잉 유동성 시대의 도래', '문제는 협력이야, 바보야', '국경 너머의 한 표', 'AI기술과 방어체제', '좋으면 맞고 싫으면 틀리다', '전현무 "경상도에서 날 쓰레기라고 하지?" 자폭', '李대통령 현 상황.. "김밥 한 줄 먹고 3시간째..."', '李 대통령, 尹정부 장관들과 4시간 국무회의…"어색해도 최선 다해달라"(종합)', "與, '내란 등 3대 특검·검사징계법' 1호 처리…李대통령 재가 전망", '"이준석, 선거비용 탓에 택시기사로.." 예언 결과', '유시민 "이재명, 대통령 되더라도..." 반전 평가', '기자에게 습격당한 권성동 VS 김혜경 여사, 드러난 태도 차이가...', '"이 음식 끊고 운동" 38kg 빼고 확 바뀐 20대女', '‘득표율 0.98%’ 권영국이 웃는 이유는 11억이...', '170㎝·41㎏ 비키니로 드러낸 몸매', "'이혼' 윰댕, 자궁 적출 고백", '"김혜경여사, 치마 입고 \'쭈구리\' 자세를..." 울컥', '권성동, 의문의 행동 논란 "李대통령과 악수 후..."', '48세 KBS 출신 女아나, 피부 나이 29세... 누구?', '전한길 "이준석은 대구시장 정도, 한동훈은.." 평가', "1인당 국민소득 '세계 6위'.. 또 日 제친 반전 국가", '대통령실 "직원들 대부분 업무복귀…조금씩 일할 수 있는 기반 마련"', '서영교·김병기 출마선언…李정부 손 맞출 與 원내 사령탑 누가 될까', '국민의힘 권성동 사퇴했지만…비대위 체제 놓고 내홍 여전', '네이버, 리박스쿨 댓글조작 정황 포착…"한 IP 다른 계정 기록"', '조희대 대법원
# ...

# %%
df = pd.DataFrame({"word":title_list})

# %%
hannanum = konlpy.tag.Hannanum()
df['word'] = df['word'].str.replace('[^가-힣]', ' ', regex = True)
nouns = df['word'].apply(hannanum.nouns)
nouns = nouns.explode()
nouns
# Out:
# 0     대통령
# 0     국토부
# 0     해수부
# 0      부산
# 0      신속
#      ...
# 69     상승
# 69     압박
# 69     금리
# 69     연속
# 69     동결
# Name: word, Length: 396, dtype: object

# %%
news_title = pd.DataFrame({'word' : nouns})

# 글자 수 추가
news_title['count'] = news_title['word'].str.len()

# 두 글자 이상 단어만 남기기
news_title = news_title.query('count >= 2')
news_title
# Out:
#    word  count
# 0   대통령    3.0
# 0   국토부    3.0
# 0   해수부    3.0
# 0    부산    2.0
# 0    신속    2.0
# ..  ...    ...
# 69   상승    2.0
# 69   압박    2.0
# 69   금리    2.0
# 69   연속    2.0
# 69   동결    2.0
#
# [342 rows x 2 columns]

# %%
words = news_title['word'].value_counts()
# 딕셔너리로 변환 (generate_from_frequencies에 필요)
dic_word = words.to_dict()

# 워드 클라우드 만들기
from wordcloud import WordCloud
wc = WordCloud(random_state=1234,
               font_path=font,
               width=400,
               height=400,
               background_color='white')

# 워드 클라우드 생성
img_wordcloud = wc.generate_from_frequencies(dic_word)

# 출력
plt.figure(figsize=(5, 5))
plt.axis('off')
plt.imshow(img_wordcloud)
plt.show()
