# %%
import pandas as pd
import matplotlib.pyplot as plt
# 한글 폰트 설정 (Windows: Malgun Gothic, macOS: AppleGothic, Linux: NanumGothic 등)
# 사용 환경에 맞는 폰트 이름을 지정해주세요.
plt.rcParams['font.family'] = 'Malgun Gothic' # Windows
# plt.rcParams['font.family'] = 'AppleGothic' # macOS
# plt.rcParams['font.family'] = 'NanumGothic' # Linux (나눔고딕 설치 필요)
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 깨짐 방지

# 예시 데이터 생성
data = {
    '월': ['1월', '2월', '3월', '4월'],
    '매출': [100, 150, 130, 170],
    '비용': [90, 100, 120, 140]
}
df = pd.DataFrame(data).set_index('월')

# %%
df.plot() # 커럼당 가로줄 1개
plt.title("월별 매출 및 비용 추이")
plt.ylabel("금액 (만원)")
plt.show()

# %%
df
# Out:
#      매출   비용
# 월
# 1월  100   90
# 2월  150  100
# 3월  130  120
# 4월  170  140

# %%
df.plot(kind='bar',figsize=(6,2),rot=0)
plt.title("월별 매출 및 비용")
plt.ylabel("금액 (만원)")
plt.show()

# %%
df.plot(kind='barh')
plt.title("월별 매출 및 비용 (수평)")
plt.show()

# %%
df.plot(kind='bar', stacked=True, figsize=(3,3))
plt.title("월별 매출과 비용 (누적)")
plt.show()

# %%
df['매출'].plot(kind='pie', autopct='%1.1f%%')
plt.title("월별 매출 구성비")
plt.ylabel("")  # y축 제거
plt.show()

# %%
df.plot(kind='hist')
plt.title("매출/비용 분포 히스토그램")
plt.show()

# %%
df.plot(kind='box')
plt.title("매출 및 비용의 박스 플롯")
plt.show()

# %%
df.plot(kind='scatter', x='매출', y='비용')
plt.title("매출과 비용의 관계")
plt.show()

# %%
import pandas as pd

mpg = pd.read_csv('./data/mpg.csv')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
# x축은 displ, y축은 hwy를 나타낸 산점도 만들기
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6)) # 그래프 크기 지정 4인치가로 4인치세로
import seaborn as sns
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy', hue='drv')
# Out:
# <Axes: xlabel='displ', ylabel='hwy'>
