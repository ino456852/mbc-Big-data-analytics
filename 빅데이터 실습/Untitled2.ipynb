# %%
import requests
# from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs

def web_get(url, encoding=""):
    response = requests.get(url,
                            cookies={"NNB": ''},
                            headers={
                                "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36"
                            })
    if encoding != "":
        response.encoding = encoding  # 유니코드로 인코딩
    html_text = response.text
    print("cookies = %s" % response.cookies.get_dict())
    return html_text  # 함수끝


def find_text(html_text, selector):
    from bs4 import BeautifulSoup as bs
    soup = bs(html_text, 'html.parser')
    return soup.select_one(selector).get_text()


def find_text_list(html_text, selector):
    from bs4 import BeautifulSoup as bs
    # html을 잘 정리된 형태로 변환
    soup = bs(html_text, 'html.parser')
    tag_list = soup.select(selector)
    result_list = []
    for tag in tag_list:
        result_list.append(tag.get_text().strip())
    return result_list

def find_link_list(html_text, selector):
    from bs4 import BeautifulSoup as bs
    # html을 잘 정리된 형태로 변환
    soup = bs(html_text, 'html.parser')
    tag_list = soup.select(selector)
    
    result_list = []
    for tag in tag_list:
        result_list.append(tag.get("href")) # 1 a태그 뽑는법
        # result_list.append(tag["href"]) # 2
    return result_list

menu_url = "https://news.naver.com/section/105"
# driver = get_browser(menu_url, False)
# html = driver.page_source
# soup = bs(html, "html.parser")
html = web_get(menu_url, encoding="utf-8")
news_title = find_text_list(html, ".sa_text .sa_text_strong")
news_press = find_text_list(html, ".sa_text .sa_text_press")
new_link = find_link_list(html, ".sa_text > a")
print(news_title,news_press,new_link)
# Out:
# cookies = {'N_SES': 'bd05c23d-4974-4a8f-82ca-d7b0460a54c9'}
# ["오픈AI, 민주당 이어 국민의힘 'AI 실세'도 만난다", '한컴, 성과 중심 보상 강화…평균 4.3% 임금 인상률 제안', '삼성 \'갤럭시S25\' 국내 200만대 판매 돌파…"전작보다 2주 빨라"', "카카오엔터 '나혼렙', 크런치롤 어워즈서 韓 애니 최초 '최고상'", '5년 간 100억 원 투입…충청권, 지역 거점 정보보호 클러스터 구축', "SKT 해킹, 첫 유출 경유지는 '디지털오션' …배후 추적에 '난항'", 'LG CNS, AI 인재 ‘1000명’ 확보 목표', '아이티센엔텍, 튜닙·NHN 등과 공공 특화 AI 솔루션 공동 개발', '공공 클라우드 판도 바꾸는 \'PPP\'…업계 "퍼블릭 클라우드 설 자리 줄어"', "버거 없는 버거킹·크보빵 없는 편의점...SPC삼립 사고 '불똥'", '[비즈톡톡] 게임업계 노조 ‘포괄임금제’ 폐지 주장에… ‘공짜 야근’ 개선이냐, ‘귀족 노조’ 볼멘소리인가', '"고객사 \'업의 본질\'에 맞게 … 최적의 조합으로 AI 설계"', '엑시노스 칩 탑재 갤럭시Z플립 7, 성능 테스트 결과는?', '고려대의료원이 플라스틱 폐기물로 의사 가운 만든 이유', '“암 정복, 우주의 기원 풀어줄 핵물리학…인프라 투자 늘려야”', '"삼성폰 최소 25%" 다시 불켜진 美 관세 리스크', '놀다보니 레벨업 … AI는 게임 즐기며 훈련중', '"중단해" 인간 명령 거부한 AI…스스로 코드 조작도 했다', "'숨겨진 3%' 질문 찾아내야 기업도 개인도 혁신", '"경영진 대답없어" 네이버노조, 최인혁 대표 복귀 반대 집회연다', 'AI 차별화 성공...200만 넘긴 갤럭시, 엣지로 분위기 잇는다', "'AI 국부펀드' 추진하는 민주당, 오픈AI와 협력 모색", '韓 반도체 투자 역성장 우려…“반도체특별법 처리 시급”', '과기정통부, 통신·플랫폼사 직접 보안점검…"피해 정황 땐 즉시 공개"', '[테크다이브] 셀 키우면 가격도 잡힌다?…꿈의 배터리 전고체의 숙제', '코닝, ‘고밀도 광섬유’로 韓 AI 데이터센터 시장 출사표', '"기술을 넘어 경험으로"…AI의 중심 이동', '[ZD 위클리 코인] 비트코인 상승세와 맞물린 알트코인 약세에 시장 혼조세', '에너지기술연구원, 2차전지 성능 저하 난제 풀었다', "국내 IT·이동통신 기업 '인공지능 전환 사업'에 사활 걸었다", '‘챗GPT’ 오픈AI, 한국 시장 진출…“수개월 안에 서울 사무소 설립”', '[인터뷰] 톰 무디 다이슨 총괄 “혁신엔 자기파괴의 용기 필요… 처음부터 재설계해 청소기 ‘뉴노멀’ 만들었다”', '선익시스템, 中 BOE 자회사에 올레도스 증착기 공급', '물리지만 않는다면…아프리카 농장의 숨은 일꾼 ‘뻐끔살무사’ [핵잼 사이언스]', '[팩플] 오픈AI 韓 상륙...제이슨 권 CSO "한국의 AI 인프라 지원"', '인간의 종료 지시 거부하는 AI 사례 첫 보고', '선순환 구조 만드는 NHN링크…콘서트에 뮤지컬 제작까지', '구글 차기 스마트폰 ‘픽셀10’ 이렇게 나온다', '구글, AI로 검색 매출 하락 가능성…"사업 모델 바꿔야"', '가상자산 제도화 기대감...랠리 달리는 비트코인', "국세청 '원클릭' 출시에도 토스에 고객 몰렸다", '"끈적한 인공 혈전으로 혈액 속 세균 흡착해 감염 치료"', '11월 발사 `누리호 4호기`·내년 5호기 발사 준비 `순항`', 'SKT, 공시지원금 40% 인상…번호이동·e심영업도 확대'] ['지디넷코리아', '매일경제', '더팩트', '뉴스1', '노컷뉴스', '이데일리', '헤럴드경제', '아이뉴스24', '지디넷코리아', '지디넷코리아', '조선비즈', '매일경제', '지디넷코리아', '지디넷코리아', '조선비즈', '뉴스1', '매일경제', '뉴스1', '매일경제', '뉴스1', '디지털타임스', '이데일리', '전자신문', '더팩트', '디지털데일리', '조선비즈', '한국경제', '지디넷코리아', '한국경제', '한국경제', '세계일보', '조선비즈', '전자신문', '서울신문', '중앙일보', '동아사이언스', '머니투데이', '지디넷코리아', '지디넷코리아', '파이낸셜뉴스', '이데일리', '연합뉴스', '디지털타임스', '머니투데이'] ['https://n.news.naver.com/mnews/article/092/0002375705', 'https://n.news
# 10  [비즈톡톡] 게임업계 노조 ‘포괄임금제’ 폐지 주장에… ‘공짜 야근’ 개선이냐, ‘...    조선비즈
# 11                 "고객사 '업의 본질'에 맞게 … 최적의 조합으로 AI 설계"    매일경제
# 12                    엑시노스 칩 탑재 갤럭시Z플립 7, 성능 테스트 결과는?  지디넷코리아
# 13                      고려대의료원이 플라스틱 폐기물로 의사 가운 만든 이유  지디넷코리아
# 14                 “암 정복, 우주의 기원 풀어줄 핵물리학…인프라 투자 늘려야”    조선비즈
# 15                       "삼성폰 최소 25%" 다시 불켜진 美 관세 리스크     뉴스1
# 16                          놀다보니 레벨업 … AI는 게임 즐기며 훈련중    매일경제
# 17                   "중단해" 인간 명령 거부한 AI…스스로 코드 조작도 했다     뉴스1
# 18                        '숨겨진 3%' 질문 찾아내야 기업도 개인도 혁신    매일경제
# 19                "경영진 대답없어" 네이버노조, 최인혁 대표 복귀 반대 집회연다     뉴스1
# 20               AI 차별화 성공...200만 넘긴 갤럭시, 엣지로 분위기 잇는다  디지털타임스
# 21                    'AI 국부펀드' 추진하는 민주당, 오픈AI와 협력 모색    이데일리
# 22                     韓 반도체 투자 역성장 우려…“반도체특별법 처리 시급”    전자신문
# 23             과기정통부, 통신·플랫폼사 직접 보안점검…"피해 정황 땐 즉시 공개"     더팩트
# 24              [테크다이브] 셀 키우면 가격도 잡힌다?…꿈의 배터리 전고체의 숙제  디지털데일리
# 25                   코닝, ‘고밀도 광섬유’로 韓 AI 데이터센터 시장 출사표    조선비즈
# 26                            "기술을 넘어 경험으로"…AI의 중심 이동    한국경제
# 27          [ZD 위클리 코인] 비트코인 상승세와 맞물린 알트코인 약세에 시장 혼조세  지디넷코리아
# 28                        에너지기술연구원, 2차전지 성능 저하 난제 풀었다    한국경제
# 29                 국내 IT·이동통신 기업 '인공지능 전환 사업'에 사활 걸었다    한국경제
# 30           ‘챗GPT’ 오픈AI, 한국 시장 진출…“수개월 안에 서울 사무소 설립”    세계일보
# 31  [인터뷰] 톰 무디 다이슨 총괄 “혁신엔 자기파괴의 용기 필요… 처음부터 재설계해 ...    조선비즈
# 32                      선익시스템, 中 BOE 자회사에 올레도스 증착기 공급    전자신문
# 33         물리지만 않는다면…아프리카 농장의 숨은 일꾼 ‘뻐끔살무사’ [핵잼 사이언스]    서울신문
# 34         [팩플] 오픈AI 韓 상륙...제이슨 권 CSO "한국의 AI 인프라 지원"    중앙일보
# 35                          인간의 종료 지시 거부하는 AI 사례 첫 보고  동아사이언스
# 36                     선순환 구조 만드는 NHN링크…콘서트에 뮤지컬 제작까지   머니투데이
# 37                          구글 차기 스마트폰 ‘픽셀10’ 이렇게 나온다  지디넷코리아
# 38                   구글, AI로 검색 매출 하락 가능성…"사업 모델 바꿔야"  지디넷코리아
