# %%
import requests
# from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs

def web_get(url, encoding=""):
    response = requests.get(url,
                            cookies={"NNB": ''},
                            headers={
                                "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36"
                            })
    if encoding != "":
        response.encoding = encoding  # 유니코드로 인코딩
    html_text = response.text
    print("cookies = %s" % response.cookies.get_dict())
    return html_text  # 함수끝


def find_text(html_text, selector):
    from bs4 import BeautifulSoup as bs
    soup = bs(html_text, 'html.parser')
    return soup.select_one(selector).get_text()


def find_text_list(html_text, selector):
    from bs4 import BeautifulSoup as bs
    # html을 잘 정리된 형태로 변환
    soup = bs(html_text, 'html.parser')
    tag_list = soup.select(selector)
    result_list = []
    for tag in tag_list:
        result_list.append(tag.get_text().strip())
    return result_list

menu_url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%A2%85%EB%A1%9C%EA%B5%AC+%EB%82%A0%EC%94%A8&ackey=q8aln84m"
# driver = get_browser(menu_url, False)
# html = driver.page_source
# soup = bs(html, "html.parser")
html = web_get(menu_url, encoding="utf-8")
week_weather = find_text_list(html, ".list_box .day")
week_date = find_text_list(html, ".list_box .date")
min_temperature = find_text_list(html, ".list_box .lowest")
max_temperature = find_text_list(html, ".list_box .highest")
print(week_weather,week_date,min_temperature,max_temperature)
# Out:
# cookies = {'page_uid': 'jvdNXwqosK8ssmQWOUGssssstqK-362763', '_naver_usersession_': 'TSjjd/6RM/3DVNJEEH6aoQ=='}
# ['오늘', '내일', '수', '목', '금', '토', '일', '월', '화', '수'] ['5.26.', '5.27.', '5.28.', '5.29.', '5.30.', '5.31.', '6.01.', '6.02.', '6.03.', '6.04.'] ['최저기온13°', '최저기온15°', '최저기온15°', '최저기온16°', '최저기온18°', '최저기온17°', '최저기온18°', '최저기온18°', '최저기온17°', '최저기온18°'] ['최고기온26°', '최고기온26°', '최고기온27°', '최고기온28°', '최고기온28°', '최고기온28°', '최고기온29°', '최고기온28°', '최고기온27°', '최고기온27°']

# %%
import pandas as pd
df = pd.DataFrame(
    {
        'date':week_weather,
        'day':week_date,
        'lowest':min_temperature,
        'highest': max_temperature
    }
)
df
# Out:
#   date    day   lowest  highest
# 0   오늘  5.26.  최저기온13°  최고기온26°
# 1   내일  5.27.  최저기온15°  최고기온26°
# 2    수  5.28.  최저기온15°  최고기온27°
# 3    목  5.29.  최저기온16°  최고기온28°
# 4    금  5.30.  최저기온18°  최고기온28°
# 5    토  5.31.  최저기온17°  최고기온28°
# 6    일  6.01.  최저기온18°  최고기온29°
# 7    월  6.02.  최저기온18°  최고기온28°
# 8    화  6.03.  최저기온17°  최고기온27°
# 9    수  6.04.  최저기온18°  최고기온27°

# %%
df.to_csv('./종로구 일기예보.csv')
print('ok')
# Out:
# ok

# %%
import requests
# from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs

def web_get(url, encoding=""):
    response = requests.get(url,
                            cookies={"NNB": ''},
                            headers={
                                "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36"
                            })
    if encoding != "":
        response.encoding = encoding  # 유니코드로 인코딩
    html_text = response.text
    print("cookies = %s" % response.cookies.get_dict())
    return html_text  # 함수끝


def find_text(html_text, selector):
    from bs4 import BeautifulSoup as bs
    soup = bs(html_text, 'html.parser')
    return soup.select_one(selector).get_text()


def find_text_list(html_text, selector):
    from bs4 import BeautifulSoup as bs
    # html을 잘 정리된 형태로 변환
    soup = bs(html_text, 'html.parser')
    tag_list = soup.select(selector)
    result_list = []
    for tag in tag_list:
        result_list.append(tag.get_text().strip())
    return result_list

def find_link_list(html_text, selector):
    from bs4 import BeautifulSoup as bs
    # html을 잘 정리된 형태로 변환
    soup = bs(html_text, 'html.parser')
    tag_list = soup.select(selector)
    
    result_list = []
    for tag in tag_list:
        result_list.append(tag.get("href")) # 1 a태그 뽑는법
        # result_list.append(tag["href"]) # 2
    return result_list

menu_url = "https://news.naver.com/section/105"
# driver = get_browser(menu_url, False)
# html = driver.page_source
# soup = bs(html, "html.parser")
html = web_get(menu_url, encoding="utf-8")
news_title = find_text_list(html, ".sa_text .sa_text_strong")
news_press = find_text_list(html, ".sa_text .sa_text_press")
new_link = find_link_list(html, ".sa_text a")
print(news_title,news_press,new_link)
# Out:
# cookies = {'N_SES': '365ad1a0-7c12-4da8-bed1-743d627916bf'}
# ...

# %%
import pandas as pd
naver_news_list = pd.DataFrame(
    {
        'title':news_title,
        'press':news_press,
        'link':new_link
    }
)
naver_news_list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 import pandas as pd
# ----> 2 naver_news_list = pd.DataFrame(
#       3     {
#       4         'title':news_title,
#       5         'press':news_press,
#       6         'link':new_link
#       7     }
#       8 )
#       9 naver_news_list
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
# ...

# %%
df.to_csv('./종로구 일기예보.csv')
print('ok')
