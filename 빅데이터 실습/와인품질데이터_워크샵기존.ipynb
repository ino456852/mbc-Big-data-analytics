# %% [markdown]
# # 🧪 와인 품질 데이터 분석 실습 - Jupyter Notebook
#
# ## 📦 1. 데이터 불러오기

# %% [markdown]
# | 컬럼명                  | 설명              |
# | -------------------- | --------------- |
# | fixed acidity        | 고정 산도           |
# | volatile acidity     | 휘발성 산도          |
# | citric acid          | 구연산             |
# | residual sugar       | 잔류 당분           |
# | chlorides            | 염화물             |
# | free sulfur dioxide  | 유리 이산화황         |
# | total sulfur dioxide | 총 이산화황          |
# | density              | 밀도              |
# | pH                   | 수소 이온 농도        |
# | sulphates            | 황산염             |
# | alcohol              | 알코올 도수          |
# | quality              | 와인 품질 (0\~10 점) |

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/refs/heads/master/winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ---
#
# ## 📘 [05장] 데이터 분석 기초
#
# ### [문제 1] 데이터 파악하기
#
# 1-1. 데이터프레임의 행과 열 개수 출력

# %%
df.shape
# Out:
# (1599, 14)

# %%
# 코드입력, 확인하세요

# %% [markdown]
# 1-2. 각 변수의 데이터 타입과 정상값 갯수 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# 코드입력, 확인하세요

# %% [markdown]
# 1-3. 수치형 변수의 기초 통계량 출력

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# 코드입력, 확인하세요

# %% [markdown]
# ---
#
# ### [문제 2] 변수명 바꾸기
#
# 2-1. 주요 컬럼명을 한글로 바꾸세요:
# - `fixed acidity` → `고정산도`
# - `volatile acidity` → `휘발산도`
# - `citric acid` → `구연산`
# - `alcohol` → `알코올`
# - `quality` → `품질`

# %%
df.rename(columns={'fixed acidity':'고정산도'},inplace=True)
df.rename(columns={'volatile acidity':'휘발산도'},inplace=True)
df.rename(columns={'citric acid':'구연산'},inplace=True)
df.rename(columns={'alcohol':'알코올'},inplace=True)
df.rename(columns={'quality':'품질'},inplace=True)
df
# Out:
#       고정산도   휘발산도   구연산  residual sugar  chlorides  free sulfur dioxide  \
# 0      7.4  0.700  0.00             1.9      0.076                 11.0
# 1      7.8  0.880  0.00             2.6      0.098                 25.0
# 2      7.8  0.760  0.04             2.3      0.092                 15.0
# 3     11.2  0.280  0.56             1.9      0.075                 17.0
# 4      7.4  0.700  0.00             1.9      0.076                 11.0
# ...    ...    ...   ...             ...        ...                  ...
# 1594   6.2  0.600  0.08             2.0      0.090                 32.0
# 1595   5.9  0.550  0.10             2.2      0.062                 39.0
# 1596   6.3  0.510  0.13             2.3      0.076                 29.0
# 1597   5.9  0.645  0.12             2.0      0.075                 32.0
# 1598   6.0  0.310  0.47             3.6      0.067                 18.0
#
#       total sulfur dioxide  density    pH  sulphates   알코올  품질 알코올강도
# ...

# %%
# 코드입력, 확인하세요

# %% [markdown]
# ---
#
# ### [문제 3] 파생변수 만들기
#
# 3-1. 알코올 도수가 10.0 이상이면 "강함", 아니면 "약함"으로 표시하는 `알코올강도` 컬럼을 추가하세요.

# %%
import numpy as np

df['알코올강도'] = np.where(df['알코올'] >= 10,'강함','약함')
df[['알코올','알코올강도']].head()
# Out:
#    알코올 알코올강도
# 0  9.4    약함
# 1  9.8    약함
# 2  9.8    약함
# 3  9.8    약함
# 4  9.4    약함

# %%
# 코드입력, 확인하세요

# %% [markdown]
# ---
#
# ## 📘 [06장] 자유자재로 데이터 가공하기

# %% [markdown]
# ---
#
# ### [문제 5] 조건에 맞는 데이터 추출
#
# 5-1. 알코올 도수 12 이상이고, 품질이 7 이상인 고급 와인

# %%
np.where((df['알코올'] >= 12) | (df['품질'] >= 7),'고급와인','일반와인')
df.sort_values(['품질','알코올강도'] ,ascending=[False,True])
# Out:
#       fixed acidity   휘발산도   구연산  residual sugar  chlorides  \
# 267             7.9  0.350  0.46             3.6      0.078
# 278            10.3  0.320  0.45             6.4      0.073
# 390             5.6  0.850  0.05             1.4      0.045
# 455            11.3  0.620  0.67             5.2      0.086
# 481             9.4  0.300  0.56             2.8      0.080
# ...             ...    ...   ...             ...        ...
# 517            10.4  0.610  0.49             2.1      0.200
# 832            10.4  0.440  0.42             1.5      0.145
# 1374            6.8  0.815  0.00             1.2      0.267
# 1469            7.3  0.980  0.05             2.1      0.061
# 1505            6.7  0.760  0.02             1.8      0.078
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 267                  15.0                  37.0  0.99730  3.35       0.86
# 278                   5.0                  13.0  0.99760  3.23       0.82
# ...

# %%
# 코드입력, 확인하세요

# %% [markdown]
# 5-2. 휘발산도 0.5 이상인 와인

# %%
df.query("휘발산도 >= 0.5")
# Out:
#       고정산도   휘발산도   구연산  residual sugar  chlorides  free sulfur dioxide  \
# 0      7.4  0.700  0.00             1.9      0.076                 11.0
# 1      7.8  0.880  0.00             2.6      0.098                 25.0
# 2      7.8  0.760  0.04             2.3      0.092                 15.0
# 4      7.4  0.700  0.00             1.9      0.076                 11.0
# 5      7.4  0.660  0.00             1.8      0.075                 13.0
# ...    ...    ...   ...             ...        ...                  ...
# 1593   6.8  0.620  0.08             1.9      0.068                 28.0
# 1594   6.2  0.600  0.08             2.0      0.090                 32.0
# 1595   5.9  0.550  0.10             2.2      0.062                 39.0
# 1596   6.3  0.510  0.13             2.3      0.076                 29.0
# 1597   5.9  0.645  0.12             2.0      0.075                 32.0
#
#       total sulfur dioxide  density    pH  sulphates   알코올  품질 알코올강도
# ...

# %%
# 코드입력, 확인하세요

# %% [markdown]
# ---
#
# ### [문제 6] 필요한 변수만 추출
#
# 6-1. 알코올, 구연산, 휘발산도, 품질만 추출

# %%
df[['알코올','구연산','휘발산도','품질']]
# Out:
#        알코올   구연산   휘발산도  품질
# 0      9.4  0.00  0.700   5
# 1      9.8  0.00  0.880   5
# 2      9.8  0.04  0.760   5
# 3      9.8  0.56  0.280   6
# 4      9.4  0.00  0.700   5
# ...    ...   ...    ...  ..
# 1594  10.5  0.08  0.600   5
# 1595  11.2  0.10  0.550   6
# 1596  11.0  0.13  0.510   6
# 1597  10.2  0.12  0.645   5
# 1598  11.0  0.47  0.310   6
#
# [1599 rows x 4 columns]

# %%
# 코드입력, 확인하세요

# %% [markdown]
# ---
#
# ### [문제 7] 순서대로 정렬
#
# 7-1. 품질 내림차순 정렬

# %%
df.sort_values(by="품질", ascending=False).head()
# Out:
#       고정산도  휘발산도   구연산  residual sugar  chlorides  free sulfur dioxide  \
# 495   10.7  0.35  0.53             2.6      0.070                  5.0
# 1403   7.2  0.33  0.33             1.7      0.061                  3.0
# 390    5.6  0.85  0.05             1.4      0.045                 12.0
# 1061   9.1  0.40  0.50             1.8      0.071                  7.0
# 1202   8.6  0.42  0.39             1.8      0.068                  6.0
#
#       total sulfur dioxide  density    pH  sulphates   알코올  품질 알코올강도
# 495                   16.0  0.99720  3.15       0.65  11.0   8    강함
# 1403                  13.0  0.99600  3.23       1.10  10.0   8    강함
# 390                   88.0  0.99240  3.56       0.82  12.9   8    강함
# 1061                  16.0  0.99462  3.21       0.69  12.5   8    강함
# 1202                  12.0  0.99516  3.35       0.69  11.7   8    강함

# %% [markdown]
# 7-2. 알코올 오름차순, 휘발산도 내림차순 정렬

# %%
df.sort_values(by=["알코올", "휘발산도"], ascending=[True, False]).head()
# Out:
#       고정산도  휘발산도   구연산  residual sugar  chlorides  free sulfur dioxide  \
# 517   10.4  0.61  0.49             2.1      0.200                  5.0
# 544   14.3  0.31  0.74             1.8      0.075                  6.0
# 1436  10.0  0.38  0.38             1.6      0.169                 27.0
# 528    8.2  0.42  0.49             2.6      0.084                 32.0
# 371    7.9  0.24  0.40             1.6      0.056                 11.0
#
#       total sulfur dioxide  density    pH  sulphates  알코올  품질 알코올강도
# 517                   16.0  0.99940  3.16       0.63  8.4   3    약함
# 544                   15.0  1.00080  2.86       0.79  8.4   6    약함
# 1436                  90.0  0.99914  3.15       0.65  8.5   5    약함
# 528                   55.0  0.99880  3.34       0.75  8.7   6    약함
# 371                   25.0  0.99670  3.32       0.87  8.7   6    약함

# %% [markdown]
# ---
#
# ### [문제 8] 파생변수 추가
#
# 8-1. 품질 점수를 기준으로 등급 컬럼 추가
# - 7점 이상 우수
# - 5~6 보통
# - 5점 미만 저급

# %%
df['등급'] = np.where(df['품질'] >= 7, '고급', 
                    np.where(df['품질'] < 5,'저급','보통')
                   )
df[['품질','등급']].head()
# Out:
#    품질  등급
# 0   5  보통
# 1   5  보통
# 2   5  보통
# 3   6  보통
# 4   5  보통

# %%
# 코드입력, 확인하세요

# %% [markdown]
# ---
#
# ## 📝 [보너스] 시각화
#
# 9-1. 알코올 도수별 평균 품질 막대그래프

# %%
df['알코올'].plot.bar()
# Out:
# <Axes: >

# %%
# 코드입력, 확인하세요
